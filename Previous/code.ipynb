# %% [markdown]
# ALGEBRA LINEAL.
# ---
#
# La compañía de seguros Sure Tomorrow quiere resolver varias tareas con la ayuda de machine learning y te pide que evalúes esa posibilidad.
#
# * Tarea 1: Encontrar clientes que sean similares a un cliente determinado. Esto ayudará a los agentes de la compañía con el marketing.
#
# * Tarea 2: Predecir si es probable que un nuevo cliente reciba un beneficio de seguro. ¿Puede un modelo de predicción entrenado funcionar mejor que un modelo dummy no entrenado? ¿Puede funcionar peor? Explica tu respuesta.
#
# * Tarea 3: Predecir la cantidad de beneficios de seguro que probablemente recibirá un nuevo cliente utilizando un modelo de regresión lineal.
#
# * Tarea 4: Proteger los datos personales de los clientes sin romper el modelo de la tarea anterior.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
clients = pd.read_csv('dataset/insurance_us.csv')
clients['Age'] = clients['Age'].astype('int')
clients['Salary'] = clients['Salary'].astype('int')
clients.info()
display(clients.head(20))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Gender              5000 non-null   int64
#  1   Age                 5000 non-null   int64
#  2   Salary              5000 non-null   int64
#  3   Family members      5000 non-null   int64
#  4   Insurance benefits  5000 non-null   int64
# dtypes: int64(5)
# memory usage: 195.4 KB
#     Gender  Age  Salary  Family members  Insurance benefits
# 0        1   41   49600               1                   0
# 1        0   46   38000               1                   1
# 2        0   29   21000               0                   0
# 3        0   21   41700               2                   0
# 4        1   28   26100               0                   0
# 5        1   43   41000               2                   1
# 6        1   39   39700               2                   0
# ...

# %%
mean_salary = clients['Salary'].mean()
print(clients.groupby('Age')['Salary'].mean().reset_index().sort_values(by='Salary',ascending=False))
# Out:
#     Age        Salary
# 38   56  43860.000000
# 24   42  41990.322581
# 1    19  41523.318386
# 32   50  41444.444444
# 11   29  41042.364532
# 7    25  40852.336449
# 28   46  40815.000000
# 27   45  40793.150685
# 22   40  40747.368421
# 3    21  40505.500000
# 4    22  40293.296651
# 8    26  40172.985782
# 10   28  40162.254902
# 13   31  40113.679245
# 30   48  40103.846154
# 9    27  39995.215311
# 15   33  39991.099476
# 19   37  39869.387755
# 17   35  39844.692737
# 20   38  39802.877698
# 34   52  39754.545455
# 45   65  39700.000000
# 0    18  39661.538462
# 12   30  39602.475248
# 43   61  39600.000000
# 16   34  39470.056497
# 14   32  39454.368932
# 26   44  39400.000000
# 6    24  39396.153846
# 2    20  39313.835897
# 29   47  39295.744681
# 37   55  39266.666667
# 23   41  39260.465116
# 25   43  39132.467532
# 18   36  39028.497409
# 21   39  38941.843972
# 31   49  38751.351351
# 36   54  38371.428571
# 5    23  38213.366337
# 41   59  37800.000000
# ...

# %%
features = clients.drop('Insurance benefits', axis= 1)
target = clients['Insurance benefits']
print('Conjunto del dataset -> ',features.shape)

train_features, v_t_features, train_target, v_t_target = train_test_split(features, target, test_size = 0.4, random_state = 12345)
print('Conjunto de entrenamiento -> ',train_features.shape)

valid_features, test_feature, valid_target, test_target = train_test_split(v_t_features, v_t_target, test_size = 0.5, random_state = 12345)
print('Conjunto de validacion -> ',valid_features.shape)
print('Conjunto de testeo -> ',test_feature.shape)
# Out:
# Conjunto del dataset ->  (5000, 4)
# Conjunto de entrenamiento ->  (3000, 4)
# Conjunto de validacion ->  (1000, 4)
# Conjunto de testeo ->  (1000, 4)

# %% [markdown]
# Tarea 1.
# ---
# Para encontrar clientes que sean similares a un cliente determinado.
#
# Esto ayudará a los agentes de la compañía con el marketing.

# %%
def nearest_neightbor_predict(train_features, train_target, new_client):
    result = []
    for i in range(train_target.shape[0]):

# %%
#np.set_printoptions(suppress=True, formatter={'float_kind':'{:0.2f}'.format})
matrix_train_features = train_features.values
#print(matrix_clients)
